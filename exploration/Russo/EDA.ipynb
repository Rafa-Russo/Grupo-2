# %% [markdown]
# # EDA: hospedagem e criminalidade em Rio de Janeiro
#
# Análise exploratória conjunta dos datasets de Airbnb e crimes.

# %%
from pathlib import Path
import geopandas as gpd
import pandas as pd

PROJECT_ROOT = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "data").is_dir()
)
DATA_DIR = PROJECT_ROOT / "data"

# %%
listings = pd.read_csv("../../data/listings.csv")
listings
# Out:
# C:\Users\rafamega\AppData\Local\Temp\ipykernel_20652\3338355115.py:1: DtypeWarning: Columns (0: host_profile_url, 1: price, 2: price_quote_checkin_date, 3: price_quote_checkout_date, 4: price_quote_raw, 5: neighborhood_overview, 6: host_since, 7: host_response_time, 8: host_response_rate, 9: host_acceptance_rate, 10: host_thumbnail_url, 11: host_neighbourhood, 12: host_verifications, 13: neighbourhood, 14: instant_bookable) have mixed types. Specify dtype option on import or set low_memory=False.
#   listings = pd.read_csv("../../data/listings.csv")
#                          id                                       listing_url  \
# 0       1025196153924029661  https://www.airbnb.com/rooms/1025196153924029661
# 1       1697400829368754530  https://www.airbnb.com/rooms/1697400829368754530
# 2                  42874066             https://www.airbnb.com/rooms/42874066
# 3       1543530193994981165  https://www.airbnb.com/rooms/1543530193994981165
# 4        831750365913119274   https://www.airbnb.com/rooms/831750365913119274
# ...                     ...                                               ...
# 179632  1651790928149305935  https://www.airbnb.com/rooms/1651790928149305935
# 179633  1652082025241101165  https://www.airbnb.com/rooms/1652082025241101165
# 179634  1652148096386184589  https://www.airbnb.com/rooms/1652148096386184589
# 179635  1652264749683808805  https://www.airbnb.com/rooms/1652264749683808805
# 179636  1652323674070723839  https://www.airbnb.com/rooms/1652323674070723839
#
#              scrape_id last_scraped           source  \
# 0       20260624212719   2026-06-25      city scrape
# 1       20260624212719   2026-06-25      city scrape
# 2       20260624212719   2026-06-25      city scrape
# 3       20260624212719   2026-06-26  previous scrape
# 4       20260624212719   2026-06-25      city scrape
# ...                ...          ...              ...
# 179632  20260330062336   2026-04-02      city scrape
# 179633  20260330062336   2026-04-02      city scrape
# 179634  20260330062336   2026-04-02      city scrape
# 179635  20260330062336   2026-04-02      city scrape
# 179636  20260330062336   2026-04-02      city scrape
#
#                                                     name  \
# 0                         Quartos disponíveis no Recreio
# 1                      Casa próxima a Floresta da Tijuca
# 2              Alugo uma vaga para sexo feminino Recreio
# 3                                Barra Vista maravilhosa
# 4                                           Suíte Rio BR
# ...                                                  ...
# 179632  Av. Atlântica | Vista Mar Incrível | Suíte Premi
# 179633         Copacabana: Praia e Conforto | 5 Hóspedes
# 179634          Amplo e bem localizado Apê em Copacabana
# 179635            Apartamento para trabalho e para casal
# 179636                                          Casa AME
#
#                                               description  \
# 0                                                     NaN
# 1       Take a break to relax in this serene oasis in ...
# 2                                                     NaN
# 3        Kick back and relax in this calm, stylish space.
# 4           Spacious and pleasant suite in a family home.
# ...                                                   ...
# 179632  Comfortable sea-facing suite in Copacabana, on...
# 179633                                                NaN
# 179634  Spacious apartment in Copacabana, just minutes...
# 179635  Keep it simple at this peaceful and centrally-...
# 179636  Casa AME is located near Maracanã Stadium, res...
#
#                                               picture_url    host_id  \
# 0       https://a0.muscache.com/pictures/hosting/Hosti...  546603190
# 1       https://a0.muscache.com/pictures/hosting/Hosti...  737983482
# 2       https://a0.muscache.com/pictures/43e779d6-58df...  341395950
# 3       https://a0.muscache.com/pictures/hosting/Hosti...  173836079
# 4       https://a0.muscache.com/pictures/miso/Hosting-...   69238992
# ...                                                   ...        ...
# 179632  https://a0.muscache.com/pictures/hosting/Hosti...  357078569
# 179633  https://a0.muscache.com/pictures/prohost-api/H...   12335830
# 179634  https://a0.muscache.com/pictures/hosting/Hosti...  513633037
# 179635  https://a0.muscache.com/pictures/hosting/Hosti...  754155809
# 179636  https://a0.muscache.com/pictures/hosting/Hosti...  436313572
#
#                                            host_url  ...  host_since  \
# 0       https://www.airbnb.com/users/show/546603190  ...         NaN
# 1       https://www.airbnb.com/users/show/737983482  ...         NaN
# 2       https://www.airbnb.com/users/show/341395950  ...         NaN
# 3       https://www.airbnb.com/users/show/173836079  ...         NaN
# 4        https://www.airbnb.com/users/show/69238992  ...         NaN
# ...                                             ...  ...         ...
# 179632  https://www.airbnb.com/users/show/357078569  ...         NaN
# 179633   https://www.airbnb.com/users/show/12335830  ...         NaN
# 179634  https://www.airbnb.com/users/show/513633037  ...         NaN
# 179635  https://www.airbnb.com/users/show/754155809  ...         NaN
# 179636  https://www.airbnb.com/users/show/436313572  ...         NaN
#
#        host_response_time host_response_rate  host_acceptance_rate  \
# 0                     NaN                NaN                   NaN
# 1                     NaN                NaN                   NaN
# 2                     NaN                NaN                   NaN
# 3                     NaN                NaN                   NaN
# 4                     NaN                NaN                   NaN
# ...                   ...                ...                   ...
# 179632                NaN                NaN                   NaN
# 179633                NaN                NaN                   NaN
# 179634                NaN                NaN                   NaN
# 179635                NaN                NaN                   NaN
# 179636                NaN                NaN                   NaN
#
#         host_thumbnail_url  host_neighbourhood  host_total_listings_count  \
# 0                      NaN                 NaN                        NaN
# 1                      NaN                 NaN                        NaN
# 2                      NaN                 NaN                        NaN
# 3                      NaN                 NaN                        NaN
# 4                      NaN                 NaN                        NaN
# ...                    ...                 ...                        ...
# 179632                 NaN                 NaN                        NaN
# 179633                 NaN                 NaN                        NaN
# 179634                 NaN                 NaN                        NaN
# 179635                 NaN                 NaN                        NaN
# 179636                 NaN                 NaN                        NaN
#
#        host_verifications neighbourhood instant_bookable
# 0                     NaN           NaN              NaN
# 1                     NaN           NaN              NaN
# 2                     NaN           NaN              NaN
# 3                     NaN           NaN              NaN
# 4                     NaN           NaN              NaN
# ...                   ...           ...              ...
# 179632                NaN           NaN              NaN
# 179633                NaN           NaN              NaN
# 179634                NaN           NaN              NaN
# 179635                NaN           NaN              NaN
# 179636                NaN           NaN              NaN
#
# [179637 rows x 88 columns]

# %%
crimes = pd.read_csv("../../data/crime_data/BaseDPEvolucaoMensalCisp.csv", encoding="latin-1", sep=";")
crimes
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp                 munic    mcirc  \
# 0         1    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 1         4    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 2         5    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 3         6    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# 4         7    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# ...     ...  ...   ...      ...   ...   ...                   ...      ...
# 38131   159    7  2026  2026m07    11     7  Cachoeiras de Macacu  3300803
# 38132   165    7  2026  2026m07    33     5           Mangaratiba  3302601
# 38133   166    7  2026  2026m07    33     5        Angra dos Reis  3300100
# 38134   167    7  2026  2026m07    43     5                Paraty  3303807
# 38135   168    7  2026  2026m07    28     5             Rio Claro  3304409
#
#          regiao  hom_doloso  ...   cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0       Capital           0  ...   NaN   NaN      21                      2
# 1       Capital           3  ...   NaN   NaN      15                      6
# 2       Capital           3  ...   NaN   NaN      47                      2
# 3       Capital           6  ...   NaN   NaN      26                      2
# 4       Capital           4  ...   NaN   NaN      10                      1
# ...         ...         ...  ...   ...   ...     ...                    ...
# 38131  Interior           0  ...   3.0   0.0      21                      3
# 38132  Interior           2  ...   8.0   0.0      40                      1
# 38133  Interior           3  ...  21.0   3.0      96                      4
# 38134   Capital           1  ...   3.0   0.0      27                      2
# 38135  Interior           0  ...   0.0   0.0       4                      2
#
#        encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                     0                0                          0
# 1                     0                1                          0
# 2                     1                0                          0
# 3                     1                0                          0
# 4                     3                0                          0
# ...                 ...              ...                        ...
# 38131                 0                0                          0
# 38132                 0                0                          0
# 38133                 0                0                          0
# 38134                 1                0                          0
# 38135                 0                0                          0
#
#        pol_civis_mortos_serv  registro_ocorrencias  fase
# 0                          0                   578     3
# 1                          0                   441     3
# 2                          0                   637     3
# 3                          0                   473     3
# 4                          0                   147     3
# ...                      ...                   ...   ...
# 38131                      0                   148     2
# 38132                      0                   180     2
# 38133                      0                   710     2
# 38134                      0                   206     2
# 38135                      0                    52     2
#
# [38136 rows x 65 columns]

# %%
cisp = gpd.read_file(
    "../../data/shape_file/CISPshp/CISPshp/cisp.shp"
)

aisp = gpd.read_file(
    "../../data/shape_file/AISPshp/SHP/aisp.shp"
)

risp = gpd.read_file(
    "../../data/shape_file/RISPshp/RISPshp/risp.shp"
)

# %% [markdown]
# # Merge Datasets

# %%
# Crimes - mes a mes - cisp, aisp, risp
# bookings - trimestral - coordenadas
# shape files - cisp, aisp, risp
